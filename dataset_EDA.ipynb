# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from eda import data_clean
df = pd.DataFrame({
    "ID" : [101,102,103,104,105,106,107,108,109,110,111,112,113,114,115],
    "Name" : ["Rohan" , "Mohit" , "Karan" , "Gaurav" , "Shivam" , "Sahil" , "Kartik" , "Rahul" , "Aryan" , "Aditya" , "Arjun" , "Abhishek" , "Manav" , "Rohit" , "Rishabh"],
    "Age" : [17,19,16,27,np.nan , 24 , np.nan , 19 , np.nan , 25 , 21 , 27 , np.nan , 28 , np.nan],
    "Salary" : [45000 , 84000 ,np.nan , 57000, 60000 , np.nan , 35000 , 74000 , 91000 , np.nan , 55000 , np.nan , 64000 , np.nan , 58000],
    "City"  : ["Delhi" , "Mumbai" , "Pune" , np.nan , "Delhi" , "Kolkata" , "Bangalore" , "Delhi" , np.nan , "Mumbai" , "Delhi" , "Chennai" , "Delhi" , np.nan , "Delhi"],
    "Country" : ["India" , "India" , "India" , "India" , "India" , np.nan , np.nan , "India", np.nan, "India" , "India" , np.nan , "India" , "India" , np.nan]   
})
cleaned_df = data_clean(df)
print(cleaned_df)
# Out:
#      ID      Name   Age   Salary       City Country
# 0   101     Rohan  17.0  45000.0      Delhi   India
# 1   102     Mohit  19.0  84000.0     Mumbai   India
# 2   103     Karan  16.0  59000.0       Pune   India
# 3   104    Gaurav  27.0  57000.0      Delhi   India
# 4   105    Shivam  22.5  60000.0      Delhi   India
# 5   106     Sahil  24.0  59000.0    Kolkata   India
# 6   107    Kartik  22.5  35000.0  Bangalore   India
# 7   108     Rahul  19.0  74000.0      Delhi   India
# 8   109     Aryan  22.5  91000.0      Delhi   India
# 9   110    Aditya  25.0  59000.0     Mumbai   India
# 10  111     Arjun  21.0  55000.0      Delhi   India
# 11  112  Abhishek  27.0  59000.0    Chennai   India
# 12  113     Manav  22.5  64000.0      Delhi   India
# 13  114     Rohit  28.0  59000.0      Delhi   India
# 14  115   Rishabh  22.5  58000.0      Delhi   India

# %%
#dataset overview
print(cleaned_df.head())
# Out:
#     ID    Name   Age   Salary    City Country
# 0  101   Rohan  17.0  45000.0   Delhi   India
# 1  102   Mohit  19.0  84000.0  Mumbai   India
# 2  103   Karan  16.0  59000.0    Pune   India
# 3  104  Gaurav  27.0  57000.0   Delhi   India
# 4  105  Shivam  22.5  60000.0   Delhi   India

# %%
#clean dataset
print(cleaned_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       15 non-null     int64
#  1   Name     15 non-null     object
#  2   Age      15 non-null     float64
#  3   Salary   15 non-null     float64
#  4   City     15 non-null     object
#  5   Country  15 non-null     object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 852.0+ bytes
# None

# %%
#check the shape of dataset (rows, columns)
print(cleaned_df.shape)
# Out:
# (15, 6)

# %%
# Missing Values Check
print(cleaned_df.isnull().sum())
# Out:
# ID         0
# Name       0
# Age        0
# Salary     0
# City       0
# Country    0
# dtype: int64

# %%
# Statistical Summary
print(cleaned_df.describe())
# Out:
#                ID        Age        Salary
# count   15.000000  15.000000     15.000000
# mean   108.000000  22.366667  61200.000000
# std      4.472136   3.568046  13681.060945
# min    101.000000  16.000000  35000.000000
# 25%    104.500000  20.000000  57500.000000
# 50%    108.000000  22.500000  59000.000000
# 75%    111.500000  24.500000  62000.000000
# max    115.000000  28.000000  91000.000000

# %%
cleaned_df.corr(numeric_only=True)
# Out:
#               ID       Age    Salary
# ID      1.000000  0.548356  0.017512
# Age     0.548356  1.000000 -0.090137
# Salary  0.017512 -0.090137  1.000000

# %%
#histogram- distribution of numerical columns
cleaned_df.hist(figsize=(8,5))
plt.show()

# %%
#Boxplot- detect outliers
sns.boxplot(data=cleaned_df)
plt.show()

# %%
# if dataset has many columns
plt.figure(figsize=(6,5))
sns.boxplot(data=cleaned_df)
plt.xticks(rotation=90)
plt.show()

# %%
def data_clean(df, target=None):
    """
    Cleans dataset by:
    - Handling missing values
    - Dropping high-null columns
    - Filling categorical and numerical values
    - Removing duplicates
    """
